# %%
import pandas as pd
from datetime import datetime
import calendar

# %%
data = pd.read_csv('bike_rental_raw.csv')
data
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0      01-01-2011 00:00       1        0           0        1   9.84  14.395
# 1      01-01-2011 01:00       1        0           0        1   9.02  13.635
# 2      01-01-2011 02:00       1        0           0        1   9.02  13.635
# 3      01-01-2011 03:00       1        0           0        1   9.84  14.395
# 4      01-01-2011 04:00       1        0           0        1   9.84  14.395
# ...                 ...     ...      ...         ...      ...    ...     ...
# 10881  19-12-2012 19:00       4        0           1        1  15.58  19.695
# 10882  19-12-2012 20:00       4        0           1        1  14.76  17.425
# 10883  19-12-2012 21:00       4        0           1        1  13.94  15.910
# 10884  19-12-2012 22:00       4        0           1        1  13.94  17.425
# 10885  19-12-2012 23:00       4        0           1        1  13.12  16.665
#
# ...

# %%
data.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
data['season'] = data['season'].map({1: 'Spring',
                                      2: 'Summer',
                                      3: 'Fall',
                                      4: 'Winter'})
data.head()
# Out:
#            datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  01-01-2011 00:00  Spring        0           0        1  9.84  14.395
# 1  01-01-2011 01:00  Spring        0           0        1  9.02  13.635
# 2  01-01-2011 02:00  Spring        0           0        1  9.02  13.635
# 3  01-01-2011 03:00  Spring        0           0        1  9.84  14.395
# 4  01-01-2011 04:00  Spring        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
data['weather'] = data['weather'].map({1: 'Clear',
                                         2: 'Mist, Few clouds',
                                         3: 'Light snow, Rain, Thunderstorm',
                                         4: 'Heavy Rain, Thunderstorm, Snow, Fog'})
data.head()
# Out:
#            datetime  season  holiday  workingday weather  temp   atemp  \
# 0  01-01-2011 00:00  Spring        0           0   Clear  9.84  14.395
# 1  01-01-2011 01:00  Spring        0           0   Clear  9.02  13.635
# 2  01-01-2011 02:00  Spring        0           0   Clear  9.02  13.635
# 3  01-01-2011 03:00  Spring        0           0   Clear  9.84  14.395
# 4  01-01-2011 04:00  Spring        0           0   Clear  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
data.weather.unique()
# Out:
# array(['Clear', 'Mist, Few clouds', 'Light snow, Rain, Thunderstorm',
#        'Heavy Rain, Thunderstorm, Snow, Fog'], dtype=object)

# %%
data.to_csv('bike_rental.csv', index=False)
